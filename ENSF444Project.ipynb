# %% [markdown]
# # ENSF 444 Project - Airbnb Price Prediction
#
# ## Group Members
# - Faris Janjua (30154612)
# - Jaden Chow (30173676)
# - Muhammad Aun Raza (30172183)

# %% [markdown]
# ## 1. Problem Overview
# Our client is StaySmart Hosting Solutions, a company that helps Airbnb hosts set competitive and profitable nightly prices for their listings. The goal of this project is to predict the nightly price of an Airbnb listing in Vancouver using machine learning.

# %% [markdown]
# ## 2. Dataset Overview

# %% [markdown]
# ## 3. Data Preprocessing

# %% [markdown]
# ## 4. Feature Selection and Train/Test Split

# %% [markdown]
# ## 5. Model 1 - Linear Regression

# %% [markdown]
# ## 6. Model 2 - Random Forest Regressor

# %% [markdown]
# ## 7. Model 3 - Gradient Boosting Regressor

# %% [markdown]
# ## 8. Model Comparison

# %% [markdown]
# ## 9. Results Visualization

# %% [markdown]
# ## 10. Interpretation of Results

# %% [markdown]
# ## 11. Ethical Considerations

# %% [markdown]
# ## 12. Deviations from Proposal

# %% [markdown]
# ## 13. Conclusion
